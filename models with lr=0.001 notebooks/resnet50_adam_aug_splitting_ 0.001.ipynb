# %%
# imports for PyTorch
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from skimage.io import imread
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torchvision import models
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Dataset, TensorDataset, random_split
import torch.nn.functional as F
# Other imports
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense

from google.colab import drive
import shutil
import random
import matplotlib.pyplot as plt
from PIL import Image  # Import the Image module from the PIL library
# Set random seed for reproducibility
import torch

# Check if the Colab runtime is GPU or CPU
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU acceleration.")
    torch.backends.cudnn.deterministic = True  # Set CuDNN to deterministic mode
else:
    device = torch.device("cpu")
    print("Using CPU.")
# Set random seed for reproducibility
random_seed = 42
torch.manual_seed(random_seed)
# If using GPU, set CUDA seed
if device.type == "cuda":
    torch.cuda.manual_seed(random_seed)
# !pip install Pillow
# Out:
# Using CPU.
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %% [markdown]
# here i used code to create out_dir and copy files with 63% for training Test: 23%
# Validation: 14%

# %%
# Mount Google Drive
from google.colab import drive

drive.mount('/content/drive')
# Define the data path
DATA_PATH = '/content/drive/MyDrive/sipakmed/sipakmed/'
# Out:
# Mounted at /content/drive

# %%
import os
import shutil
import random

# Define the subsets (train, validation, and test) and their ratios
subsets = ["train", "val", "test"]
split_ratios = [0.63, 0.14, 0.23]

# Define the class labels
classes = ["normal", "atypical"]

# Create output directories if they don't exist
output_dir = '/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training'  # Set your desired output directory
for subset in subsets:
    for class_label in classes:
        subset_dir = os.path.join(output_dir, subset, class_label)
        os.makedirs(subset_dir, exist_ok=True)

# Function to check if a file has already been copied
def has_been_copied(file, destination_subset):
    class_name = "normal" if "normal" in file else "atypical"
    dest_path = os.path.join(output_dir, destination_subset, class_name, os.path.basename(file))
    return os.path.exists(dest_path)

# Function to record copied files
def record_copied_files(copied_files, destination_subset):
    with open(f'copied_files_{destination_subset}.txt', 'a') as file:
        for copied_file in copied_files:
            file.write(copied_file + '\n')

# Get a list of all image file paths
drive_path = '/content/drive/MyDrive/sipakmed/sipakmed/'  # Set your input directory containing image files
file_paths = []
for root, dirs, files in os.walk(drive_path):
    for file in files:
        if file.endswith('.bmp'):
            file_paths.append(os.path.join(root, file))

# Initialize empty lists for train, val, and test files
train_files = []
val_files = []
test_files = []

# Loop through each class, organize files, and split the data
for class_label in classes:
    class_dir = os.path.join(drive_path, class_label)
    file_list = [file for file in file_paths if class_label in file]

    # Shuffle the file list for random sampling
    random.shuffle(file_list)

    # Split the data based on the defined ratios
    num_files = len(file_list)
    split_points = [
        0,
        int(split_ratios[0] * num_files),
        int((split_ratios[0] + split_ratios[1]) * num_files),
        num_files,
    ]

    train_files += file_list[split_points[0]:split_points[1]]
    val_files += file_list[split_points[1]:split_points[2]]
    test_files += file_list[split_points[2]:split_points[3]]

def copy_files(source_files, destination_subset):
    copied_files = []
    for file in source_files:
        if not has_been_copied(file, destination_subset):
            class_name = "normal" if "normal" in file else "atypical"
            dest_path = os.path.join(output_dir, destination_subset, class_name, os.path.basename(file))
            if not os.path.exists(dest_path):
                shutil.copy(file, dest_path)
                copied_files.append(file)
                print(f"Copied {file} to {dest_path}")
            else:
                print(f"File {file} already exists in {destination_subset}")
        else:
            print(f"File {file} has already been copied to {destination_subset}")
    return copied_files

# %% [markdown]
# i used this to make sure there isn't duplicated data and data for training was succesful

# %%
import os

# Define the path to your original dataset directory
original_dataset_path = '/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_train/'

# Get a list of all image files in the original dataset directory and its subfolders
original_files = []
for root, dirs, files in os.walk(original_dataset_path):
    for filename in files:
        if filename.endswith('.bmp'):
            original_files.append(filename)

# Count the number of unique files in the original dataset
original_file_count = len(original_files)

# List files that are in the current dataset but not in the original
extra_files = []
current_dataset_path = '/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/'

for root, dirs, files in os.walk(current_dataset_path):
    for filename in files:
        if filename.endswith('.bmp') and filename not in original_files:
            extra_files.append(os.path.join(root, filename))

if extra_files:
    print("Number of extra files found in the current dataset:", len(extra_files))
    print("Duplicated files found in the current dataset:")
    for file in extra_files:
        print(file)

    # Prompt the user for confirmation before removal
    user_confirmation = input("Do you want to remove these duplicated files? (yes/no): ")

    if user_confirmation.lower() == "yes":
        # Remove the duplicated files
        for extra_file in extra_files:
            os.remove(extra_file)
        print("Duplicated files have been removed.")
    else:
        print("No files have been removed. Your dataset is safe.")
else:
    print("No duplicated files found in the current dataset.")
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/062_12.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/185_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/042_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/002_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/043_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/185_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/117_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/082_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/085_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/082_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/071_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/026_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/205_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/243_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/050_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/098_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/022_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/162_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/108_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/048_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/213_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/030_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/063_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/083_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/138_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/082_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/180_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/239_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/001_12.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/029_12.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/077_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/082_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/106_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/049_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/028_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/096_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/208_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/075_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/202_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/198_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/210_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/047_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/193_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/099_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/054_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/015_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/046_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/061_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/062_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/099_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/026_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/105_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/034_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/094_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/107_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/050_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/092_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/071_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/021_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/035_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/201_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/235_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/036_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/109_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/059_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/254_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/056_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/053_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/083_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/098_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/009_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/072_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/068_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/184_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/014_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/230_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/167_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/067_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/080_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/086_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/072_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/041_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/013_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/193_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/036_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/015_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/263_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/124_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/080_12.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/024_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/040_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/232_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/055_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/020_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/053_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/050_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/046_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/072_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/027_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/264_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/097_15.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/003_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/097_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/064_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/201_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/116_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/014_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/179_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/100_15.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/055_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/194_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/067_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/010_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/103_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/249_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/053_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/236_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/006_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/045_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/017_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/011_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/019_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/264_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/102_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/080_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/043_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/262_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/124_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/227_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/029_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/011_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/164_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/139_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/246_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/009_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/027_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/217_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/052_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/017_18.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/002_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/265_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/256_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/087_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/007_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/106_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/264_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/105_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/082_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/076_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/074_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/057_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/017_20.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/045_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/006_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/026_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/046_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/032_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/076_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/067_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/027_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/019_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/170_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/023_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/008_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/018_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/083_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/061_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/007_15.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/092_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/194_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/098_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/141_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/096_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/065_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/221_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/019_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/261_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/034_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/069_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/106_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/093_24.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/092_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/064_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/086_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/100_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/113_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/120_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/066_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/081_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/197_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/029_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/255_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/059_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/141_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/203_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/121_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/001_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/070_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/032_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/007_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/045_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/132_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/031_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/002_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/105_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/017_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/223_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/052_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/001_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/267_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/004_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/061_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/038_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/007_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/002_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/116_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/022_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/099_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/012_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/129_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/089_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/009_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/024_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/038_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/204_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/081_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/264_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/016_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/164_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/003_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/005_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/056_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/118_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/238_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/055_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/138_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/102_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/075_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/020_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/034_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/059_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/014_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/008_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/049_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/104_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/039_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/001_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/078_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/016_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/244_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/099_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/101_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/043_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/142_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/047_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/027_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/066_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/104_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/098_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/012_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/122_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/017_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/146_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/002_15.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/095_17.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/078_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/173_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/040_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/052_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/052_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/normal/088_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_22.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/009_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/213_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/120_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/019_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/106_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/002_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/013_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/013_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/054_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/057_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/090_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/043_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/104_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/144_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/042_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/217_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/075_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/122_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/063_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/016_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/072_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/108_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/064_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/052_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/067_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/006_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/086_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/026_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_20.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/138_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/138_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/117_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/123_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_16.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/059_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_23.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/129_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/005_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/167_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/178_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/073_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/090_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/040_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/017_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/059_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/149_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_18.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/015_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/071_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/092_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/147_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/022_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/088_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/195_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/134_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/184_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/064_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/102_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/221_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/110_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/112_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/083_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/096_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/163_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/016_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/069_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/078_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/172_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/089_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/102_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/002_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/019_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_21.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_18.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/095_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/047_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/121_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/114_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/003_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/122_16.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/101_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/217_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/091_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/175_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/038_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/156_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/130_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/095_16.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/036_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/102_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/073_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/167_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/101_16.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/013_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/025_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/115_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/017_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/216_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/158_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/052_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/095_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/007_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/055_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/018_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/205_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/127_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/218_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/155_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/025_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/031_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/076_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/107_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/007_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/117_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/206_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/087_15.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/121_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/191_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/114_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/157_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/117_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/025_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/219_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/079_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/180_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/017_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/111_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/034_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/130_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/063_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/019_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/059_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/190_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/202_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/216_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/104_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/150_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/085_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/087_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/118_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/135_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/196_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/214_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/069_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/068_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/225_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/062_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/224_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/159_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/096_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/072_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/136_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/124_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/085_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/133_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/090_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/163_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/067_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/020_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/124_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/046_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/154_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/067_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/071_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/221_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/238_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/084_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/219_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/046_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/099_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/072_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/136_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/160_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/023_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/147_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/117_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/089_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/117_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/221_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/161_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/125_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/198_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/221_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/203_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/208_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/088_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/066_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/038_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/142_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/001_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/019_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/163_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/126_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/128_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/098_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/035_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/088_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/135_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/166_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/084_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/029_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/124_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/049_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/087_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/127_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/086_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/011_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/119_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/215_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/020_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/037_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_19.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/024_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/148_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/113_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/195_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/114_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/140_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/015_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/211_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/099_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/005_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/067_17.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/183_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/145_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/130_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/133_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/121_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/111_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/040_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/019_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/009_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/110_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/023_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/060_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/138_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/146_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/216_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/164_15.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/161_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/146_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/109_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/031_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/024_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/139_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/122_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/149_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/083_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/011_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/119_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/109_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/099_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/105_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/121_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/006_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/062_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/132_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/192_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/157_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/144_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/141_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/117_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/121_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/097_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/163_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/102_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/027_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/114_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/011_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/138_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/094_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/169_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/109_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/087_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/130_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/039_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/002_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/072_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/133_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/104_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/054_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/237_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/156_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/159_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/114_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/217_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/087_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/train/atypical/009_01.bmp
# ...
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/125_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/043_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/237_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/167_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/028_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/004_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/097_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/069_12.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/269_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/165_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/106_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/260_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/095_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/004_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/210_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/025_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/078_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/042_12.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/097_16.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/003_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/078_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/031_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/226_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/020_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/095_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/017_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/017_21.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/047_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/099_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/250_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/148_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/189_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/089_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/040_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/102_12.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/066_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/005_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/123_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/078_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/069_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/101_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/008_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/012_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/010_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/097_14.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/023_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/207_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/044_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/012_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/101_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/095_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/062_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/001_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/098_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/020_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/217_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/031_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/175_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/016_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/023_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/228_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/138_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/071_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/129_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/116_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/009_09.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/065_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/004_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/124_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/046_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/246_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/227_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/236_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/091_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/084_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/241_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/089_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/146_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/069_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/113_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/094_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/054_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/123_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/052_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/008_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/074_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/166_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/077_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/070_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/269_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/073_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/106_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/080_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/049_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/264_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/062_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/032_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/011_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/208_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/060_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/231_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/202_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/018_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/093_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/011_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/024_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/116_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/094_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/119_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/071_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/074_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/126_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/269_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/122_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/099_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/108_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/033_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/015_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/075_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/071_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/098_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/021_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/132_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/095_16.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/003_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/095_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/037_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/193_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/093_16.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/045_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/009_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/259_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/025_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/202_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/073_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/243_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/062_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/217_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/268_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/075_13.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/245_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/228_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/007_11.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/108_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/135_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/021_07.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/022_03.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/019_08.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/054_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/047_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/154_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/022_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/014_02.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/118_05.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/049_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/039_01.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/218_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/261_10.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/059_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/070_04.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/007_06.bmp
# /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/processed_classified/Normal/117_03.bmp
# Do you want to remove these duplicated files? (yes/no): n
# No files have been removed. Your dataset is safe.

# %% [markdown]
# i used this to check now how many files i have knowing that my data for sipakmed originally were 4049 bmb files

# %%
# Get a list of all image file paths
file_paths = []
categories = []

for root, dirs, files in os.walk(DATA_PATH):
    for file in files:
        if file.endswith('.bmp'):
            file_path = os.path.join(root, file)
            file_paths.append(file_path)
            if 'normal' in file_path:
                categories.append(0)
            else:
                categories.append(1)

# %%
# Create a DataFrame
df = pd.DataFrame({'filename (X)': file_paths, 'category (Y)': categories})
df
# Out:
#                                             filename (X)  category (Y)
# 0      /content/drive/MyDrive/sipakmed/sipakmed/norma...             0
# 1      /content/drive/MyDrive/sipakmed/sipakmed/norma...             0
# 2      /content/drive/MyDrive/sipakmed/sipakmed/norma...             0
# 3      /content/drive/MyDrive/sipakmed/sipakmed/norma...             0
# 4      /content/drive/MyDrive/sipakmed/sipakmed/norma...             0
# ...                                                  ...           ...
# 11767  /content/drive/MyDrive/sipakmed/sipakmed/proce...             1
# 11768  /content/drive/MyDrive/sipakmed/sipakmed/proce...             1
# 11769  /content/drive/MyDrive/sipakmed/sipakmed/proce...             1
# 11770  /content/drive/MyDrive/sipakmed/sipakmed/proce...             1
# 11771  /content/drive/MyDrive/sipakmed/sipakmed/proce...             1
#
# [11772 rows x 2 columns]

# %%
import os
import shutil
import random
# Specify the path to your dataset on Google Drive
drive_path = '/content/drive/MyDrive/sipakmed/sipakmed/'

# Define the output directory for your divided dataset on Google Drive
output_dir = '/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training'

# %% [markdown]
# to check if my data are balanced regarding the training ones or not

# %%
import os
import matplotlib.pyplot as plt

# Define the root directories to check
directories = [
    '/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/',
    '/content/drive/MyDrive/sipakmed/sipakmed/'
]

# Function to count BMP files recursively in a directory
def count_bmp_files_recursive(root_dir):
    count = 0
    for root, dirs, files in os.walk(root_dir):
        count += sum(1 for file in files if file.endswith('.bmp'))
    return count

# Iterate over the directories and count the files
counts = []
dir_names = []

for directory in directories:
    file_count = count_bmp_files_recursive(directory)
    counts.append(file_count)
    dir_names.append(directory)
# Print the counts for the specified directories
for name, count in zip(dir_names, counts):
    print(f"Directory: {name}, BMP File Count: {count}")

# Count BMP files in all directories inside both root directories
original_count = count_bmp_files_recursive('/content/drive/MyDrive/sipakmed/sipakmed/')
training_count = count_bmp_files_recursive('/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/')

print(f"Total BMP File Count in '/content/drive/MyDrive/sipakmed/sipakmed/': {original_count}")
print(f"Total BMP File Count in '/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/': {training_count}")



# Create a bar plot
plt.figure(figsize=(10, 6))
plt.bar(dir_names + ['Total Original', 'Total Training'], counts + [original_count, training_count], color='skyblue')
plt.xlabel('Directories')
plt.ylabel('BMP File Count')
plt.title('BMP File Counts in Specified Directories')
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# Directory: /content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/, BMP File Count: 5886
# Directory: /content/drive/MyDrive/sipakmed/sipakmed/, BMP File Count: 11772
# Total BMP File Count in '/content/drive/MyDrive/sipakmed/sipakmed/': 11772
# Total BMP File Count in '/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/': 5886

# %% [markdown]
# data balance in normal and atypical

# %%
# Function to balance data by randomly undersampling the majority class
def balance_data(train_files):
    normal_files = [file for file in train_files if 'normal' in file]
    atypical_files = [file for file in train_files if 'atypical' in file]

    min_samples = min(len(normal_files), len(atypical_files))

    balanced_data = random.sample(normal_files, min_samples) + random.sample(atypical_files, min_samples)
    return balanced_data

# %%
def check_balance(data):
    normal_count = sum(1 for file in data if 'normal' in file)
    atypical_count = sum(1 for file in data if 'atypical' in file)

    return normal_count, atypical_count

# Call the balance_data function to get the balanced dataset
balanced_train_data = balance_data(train_files)

# Check the balance
normal_count, atypical_count = check_balance(balanced_train_data)
print(f"Normal samples: {normal_count}, Atypical samples: {atypical_count}")

if normal_count == atypical_count:
    print("The data is balanced.")
else:
    print("The data is not balanced.")
# Out:
# Normal samples: 2179, Atypical samples: 2179
# The data is balanced.

# %% [markdown]
# Data preprocessing and loading using torchvision

# %% [markdown]
#  load images and their labels from the balanced_dataset:

# %%
import os
import torch
from torchvision import transforms
from PIL import Image

# Constants
IMAGE_HEIGHT = 125
IMAGE_WIDTH = 125
BASE_PATH = "/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/"
DATA_PATH = os.path.join(BASE_PATH, "train")
SAVE_PATH = os.path.join(BASE_PATH, "preprocessed_classified/")

# Helper functions

def get_processed_files(original_files, save_path):
    processed_files = []
    for orig in original_files:
        processed = get_processed_path(orig, save_path)
        if os.path.exists(processed):
            processed_files.append(processed)
    return processed_files

def get_processed_path(orig_path, save_path):
    filename = os.path.basename(orig_path)
    processed_name = f"{filename.replace('.bmp', '_processed.pt')}"
    return os.path.join(save_path, processed_name)

def is_bmp_file(filepath):
    return filepath.lower().endswith('.bmp')

def load_processed_images(processed_paths):
    X = []
    for p in processed_paths:
        img = torch.load(p)
        X.append(img)
    return torch.stack(X)

def load_and_process_images(original_files, data_path, transform, save_path):
    X_normal = []
    X_atypical = []

    for orig in original_files:
        if not is_bmp_file(orig):
            continue  # Skip non-BMP files

        img = Image.open(orig)
        img = transform(img)
        save_name = get_processed_path(orig, save_path)

        # Classify based on the subfolder
        class_label = "normal" if "normal" in orig else "atypical"
        class_save_path = os.path.join(save_path, class_label)

        os.makedirs(class_save_path, exist_ok=True)
        torch.save(img, os.path.join(class_save_path, os.path.basename(save_name)))

        # Append to the respective lists
        if class_label == "normal":
            X_normal.append(img)
        else:
            X_atypical.append(img)

    return torch.stack(X_normal), torch.stack(X_atypical)

# Check for subfolders "Normal" and "Atypical" inside "train"
if not (os.path.exists(os.path.join(DATA_PATH, "normal")) and os.path.exists(os.path.join(DATA_PATH, "atypical"))):
    print("Error: The 'train' directory does not contain the expected subfolders 'normal' and 'atypical'.")
    exit()

# Prompt to apply data processing
apply_processing = input("Do you want to apply data processing? (y/n): ").lower() == 'y'

if apply_processing:
    # Transform for data augmentation during processing
    transform = transforms.Compose([
        transforms.Resize((IMAGE_HEIGHT, IMAGE_WIDTH)),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(degrees=15),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Get list of original image files
    original_files = []
    for root, dirs, files in os.walk(DATA_PATH):
        for filename in files:
            if filename.endswith(".bmp"):
                original_files.append(os.path.join(root, filename))

    # Print the number of original images
    print("Number of original images:", len(original_files))

    # Check for processed images
    processed_files = get_processed_files(original_files, SAVE_PATH)
    if len(processed_files) == len(original_files):
        print("Using existing processed images")
        # Specify whether data augmentation was applied during processing
        augmentation_info = "with augmentation" if 'Random' in str(transform) else "without augmentation"
        print(f"Images were processed {augmentation_info}")
        X_train_normal, X_train_atypical = load_and_process_images(original_files, DATA_PATH, transform, SAVE_PATH)
    else:
        print("Processing images...")
        # Specify whether data augmentation is applied during processing
        augmentation_info = "with augmentation" if 'Random' in str(transform) else "without augmentation"
        print(f"Images are being processed {augmentation_info}")
        X_train_normal, X_train_atypical = load_and_process_images(original_files, DATA_PATH, transform, SAVE_PATH)

        # Print the number of processed images
        print("Number of processed images (normal):", len(X_train_normal))
        print("Number of processed images (atypical):", len(X_train_atypical))

        if len(X_train_normal) + len(X_train_atypical) != len(original_files):
            print("Error: Mismatch between the number of processed and original images.")
else:
    print("Data processing skipped.")

# Rest of your code...
# Print the number of images in each class after moving
normal_dir = os.path.join(SAVE_PATH, "normal")
atypical_dir = os.path.join(SAVE_PATH, "atypical")
print("Number of images in 'normal' class:", len(os.listdir(normal_dir)))
print("Number of images in 'atypical' class:", len(os.listdir(atypical_dir)))
# Out:
# Do you want to apply data processing? (y/n): n
# Data processing skipped.
# Number of images in 'normal' class: 1159
# Number of images in 'atypical' class: 1005

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import torch.nn.functional as F
import os
from torchvision.models import resnet50  # Import ResNet-50
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import time

# Model
class ResNet50Model(nn.Module):
    def __init__(self, num_classes=2):
        super(ResNet50Model, self).__init__()
        self.model = resnet50(pretrained=True)
        in_features = self.model.fc.in_features
        self.model.fc = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.model(x)

from torchvision import transforms

# Update the PTImageDataset class
class PTImageDataset(Dataset):
    def __init__(self, data_dir, transform=None):
        self.data_dir = data_dir
        self.files = self.get_files(data_dir)
        self.num_classes = 2  # Assuming you have 2 classes
        self.class_names = ["normal", "abnormal"]
        self.transform = transform

    def __len__(self):
        return len(self.files)

    def __getitem__(self, idx):
        img_path = self.files[idx]
        img_tensor = torch.load(img_path)

        # Apply transformations if specified
        if self.transform:
            img_tensor = self.transform(img_tensor)

        # Extract label from the file path or filename
        label = self.extract_label(img_path)

        return img_tensor, label

    def extract_label(self, file_path):
        # Modify this logic based on your actual file naming or directory structure
        parts = file_path.split(os.path.sep)
        class_name = parts[-2]
        return 0 if class_name == "normal" else 1  # Adjust based on your class names

    def get_files(self, data_dir):
        all_files = []
        for root, dirs, files in os.walk(data_dir):
            for file in files:
                if file.endswith(".pt"):
                    all_files.append(os.path.join(root, file))
        return all_files

# Define transformations for training and validation/test
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to ResNet-50 input size
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Use the modified PTImageDataset with transformations
dataset = PTImageDataset(PREPROCESSED_PATH, transform=train_transform)

# %%
# Training function
def train(model, train_loader, criterion, optimizer):
    model.train()
    epoch_loss = 0
    epoch_acc = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        epoch_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs.data, 1)
        total = labels.size(0)
        correct = (predicted == labels).sum().item()
        epoch_acc += correct / total

    epoch_loss /= len(train_loader.dataset)
    epoch_acc /= len(train_loader.dataset)

    return epoch_loss, epoch_acc

# Placeholder for the test function
def test(model, test_loader, criterion):
    model.eval()
    epoch_loss = 0
    epoch_acc = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)

            epoch_loss += criterion(outputs, labels).item() * inputs.size(0)
            _, predicted = torch.max(outputs.data, 1)
            total = labels.size(0)
            correct = (predicted == labels).sum().item()
            epoch_acc += correct

            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    epoch_loss /= len(test_loader.dataset)
    epoch_acc /= len(test_loader.dataset)

    return epoch_loss, epoch_acc, all_preds, all_labels

# Dataset and dataloaders
PREPROCESSED_PATH = "/content/drive/MyDrive/sipakmed/sipakmed/sipakmed_training/preprocessed_classified/"
dataset = PTImageDataset(PREPROCESSED_PATH)
total_size = len(dataset)
train_size = int(0.6 * total_size)
val_size = int(0.2 * total_size)
test_size = total_size - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
import os
from torchvision.models import resnet50
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score, precision_score, recall_score

# Model, optimizer, loss
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ResNet50Model().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

# Check if a pre-trained model should be loaded
load_pretrained = input("Do you want to load a pre-trained model? (yes/no): ").lower()

if load_pretrained == "yes":
    # Check if a previously saved model exists
    saved_model_path = "resnet50_adam.pth"  # Adjust the filename as needed
    if os.path.exists(saved_model_path):
        model.load_state_dict(torch.load(saved_model_path))
        print("Pre-trained model loaded.")
    else:
        print(f"No pre-trained model found at {saved_model_path}. Training a new model.")
        load_pretrained = "no"

if load_pretrained != "yes":
    # Training loop
    train_losses = []
    train_accuracies = []
    validation_losses = []
    validation_accuracies = []

    # Early stopping
    patience = 5
    best_val_loss = float('inf')  # Initialize here
    epochs_no_improve = 0

    for epoch in range(50):
        # Training
        train_loss, train_acc = train(model, train_loader, criterion, optimizer)

        # Validation
        val_loss, val_acc, _, _ = test(model, val_loader, criterion)

        print(f"Epoch {epoch + 1} - "
              f"Train Loss: {train_loss:.4f} Train Acc: {train_acc:.4f} "
              f"Validation Loss: {val_loss:.4f} Validation Acc: {val_acc:.4f}")

        # Append metrics for later plotting
        train_losses.append(train_loss)
        train_accuracies.append(train_acc)
        validation_losses.append(val_loss)
        validation_accuracies.append(val_acc)

        # Early stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1

        if epochs_no_improve == patience:
            print("Early stopping!")
            break

    # Testing
    test_loss, test_acc, test_preds, test_labels = test(model, test_loader, criterion)
    print(f"Final Test Loss: {test_loss:.4f} Test Acc: {test_acc:.4f}")
# Out:
# Do you want to load a pre-trained model? (yes/no): n
# Epoch 1 - Train Loss: 0.4517 Train Acc: 0.0530 Validation Loss: 0.3813 Validation Acc: 0.8218
# Epoch 2 - Train Loss: 0.3632 Train Acc: 0.0539 Validation Loss: 0.3373 Validation Acc: 0.9306
# Epoch 3 - Train Loss: 0.2823 Train Acc: 0.0556 Validation Loss: 0.1407 Validation Acc: 0.9375
# Epoch 4 - Train Loss: 0.2877 Train Acc: 0.0560 Validation Loss: 0.1713 Validation Acc: 0.9444
# Epoch 5 - Train Loss: 0.2146 Train Acc: 0.0584 Validation Loss: 0.2309 Validation Acc: 0.9352
# Epoch 6 - Train Loss: 0.2071 Train Acc: 0.0581 Validation Loss: 0.2550 Validation Acc: 0.9097
# Epoch 7 - Train Loss: 0.1703 Train Acc: 0.0590 Validation Loss: 0.1719 Validation Acc: 0.9329
# Epoch 8 - Train Loss: 0.1693 Train Acc: 0.0589 Validation Loss: 0.1968 Validation Acc: 0.9421
# Early stopping!
# Final Test Loss: 0.1784 Test Acc: 0.9378

# %%
# Plot training and validation loss curves
plt.plot(train_losses, label='Training Loss')
plt.plot(validation_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.figure(figsize=(8, 8))
plt.show()

# %%
# Plot confusion matrix
cm = confusion_matrix(test_labels, test_preds)
plt.figure(figsize=(8, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
plt.show()

# %%
# Additional metrics
f1 = f1_score(test_labels, test_preds, average='weighted')
precision = precision_score(test_labels, test_preds, average='weighted')
recall = recall_score(test_labels, test_preds, average='weighted')

print(f"F1 Score: {f1:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")

# Classification report
class_report = classification_report(test_labels, test_preds, target_names=dataset.class_names)
print("Classification Report:\n", class_report)

# Save the model
save_model = input("Do you want to save the trained model? (yes/no): ").lower()
if save_model == "yes":
    model_save_path = "resnet50_adam_aug.pth"  # Adjust the filename as needed
    torch.save(model.state_dict(), model_save_path)
    print("Model saved.")
# Out:
# F1 Score: 0.9374
# Precision: 0.9416
# Recall: 0.9378
# Classification Report:
#                precision    recall  f1-score   support
#
#       normal       0.91      0.99      0.94       233
#     abnormal       0.98      0.88      0.93       201
#
#     accuracy                           0.94       434
#    macro avg       0.94      0.93      0.94       434
# weighted avg       0.94      0.94      0.94       434
#
# Do you want to save the trained model? (yes/no): y

# %% [markdown]
#  Evaluation Metrics:
#  - F1 Score (0.9374): A balanced measure of precision and recall.
#  - Precision (0.9416): The accuracy of positive predictions.
#  - Recall (0.9378): The ability to identify all relevant instances.
#  - Classification Report: Detailed metrics for each class ("normal" and "abnormal").
#    - For "normal": High precision (few false positives), moderate recall.
#    - For "abnormal": Good precision, very high recall (few false negatives).
#  - Accuracy (0.94): Overall correct predictions.
#  - Macro Avg and Weighted Avg: Averages for precision, recall, and F1-score.
# In summary, the model seems to perform well with a good balance between precision and recall. The detailed classification report provides insights into the performance for each class.

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

num_params = count_parameters(model)
print(f"Number of trainable parameters in the model: {num_params}")
# Out:
# Number of trainable parameters in the model: 23512130

# %%
import time

# Use a sample input for inference
sample_input = torch.randn(1, 3, 125, 125).to(device)

# Measure inference time
model.eval()
with torch.no_grad():
    start_time = time.time()
    _ = model(sample_input)
    inference_time = time.time() - start_time

print(f"Inference time for a sample input: {inference_time} seconds")
# Out:
# Inference time for a sample input: 0.1427617073059082 seconds
